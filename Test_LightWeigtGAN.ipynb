# %% [markdown]
# **Download and Unzip the Dataset**

# %%
# !git clone https://github.com/matthuisman/gdrivedl
# !python3 gdrivedl/gdrivedl.py "https://drive.google.com/uc?id=1aAJCZbXNHyraJ6Mi13dSbe7pTyfPXha0&export=download"
# Out:
# Cloning into 'gdrivedl'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 235 (delta 43), reused 48 (delta 37), pack-reused 169
# Receiving objects: 100% (235/235), 8.39 MiB | 21.26 MiB/s, done.
# Resolving deltas: 100% (101/101), done.
# ./few-shot-image-datasets.zip 870.25MB

# %%
# %%capture
# !unzip few-shot-image-datasets.zip

# %% [markdown]
# **Clone the Lightweight-GAN repo and train it on the extracted dataset**

# %%
# !git clone https://github.com/kk-digital/lightweight-gan.git
# !pip3 install ./lightweight-gan

# %%
! lightweight_gan --data ./few-shot-images/100-shot-grumpy_cat/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/100-shot-obama/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/100-shot-panda/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/AnimalFace-cat/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/AnimalFace-dog/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/anime-face/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/art-painting/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/fauvism-still-life/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/flat-colored/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/moongate/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/pokemon/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/shells/ --image-size 256

# %%
! lightweight_gan --data ./few-shot-images/skulls/ --image-size 256
